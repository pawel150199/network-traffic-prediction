# %%
import os.path as osp
import time

import torch
import torch.nn.functional as F

from torch_geometric.datasets import Entities
from torch_geometric.nn import RGATConv


from import_data import import_data

dataset = "Euro28"
data, results = import_data(dataset)

data = data
labels = results[:,2]


class RGAT(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels,
                 num_relations):
        super().__init__()
        self.conv1 = RGATConv(in_channels, hidden_channels, num_relations)
        self.conv2 = RGATConv(hidden_channels, hidden_channels, num_relations)
        self.lin = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, x, edge_index, edge_type):
        x = self.conv1(x, edge_index, edge_type).relu()
        x = self.conv2(x, edge_index, edge_type).relu()
        x = self.lin(x)
        return F.log_softmax(x, dim=-1)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
data = data.to(device)
model = RGAT(16, 16, dataset.num_classes, dataset.num_relations).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=0.0005)


def train():
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index, data.edge_type)
    loss = F.nll_loss(out[data.train_idx], data.train_y)
    loss.backward()
    optimizer.step()
    return float(loss)


@torch.no_grad()
def test():
    model.eval()
    pred = model(data.x, data.edge_index, data.edge_type).argmax(dim=-1)
    train_acc = float((pred[data.train_idx] == data.train_y).float().mean())
    test_acc = float((pred[data.test_idx] == data.test_y).float().mean())
    return train_acc, test_acc


times = []
for epoch in range(1, 51):
    start = time.time()
    loss = train()
    train_acc, test_acc = test()
    print(f'Epoch: {epoch:02d}, Loss: {loss:.4f}, Train: {train_acc:.4f} '
          f'Test: {test_acc:.4f}')
    times.append(time.time() - start)
print(f"Median time per epoch: {torch.tensor(times).median():.4f}s")
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!
# Epoch: 001, Train: 0.1429, Val: 0.0580, Test: 0.0640
# Epoch: 002, Train: 0.1429, Val: 0.0580, Test: 0.0640
# Epoch: 003, Train: 0.1429, Val: 0.0580, Test: 0.0640
# Epoch: 004, Train: 0.1786, Val: 0.0920, Test: 0.1230
# Epoch: 005, Train: 0.4714, Val: 0.4060, Test: 0.4190
# Epoch: 006, Train: 0.3929, Val: 0.4060, Test: 0.4190
# Epoch: 007, Train: 0.3071, Val: 0.4060, Test: 0.4190
# Epoch: 008, Train: 0.3714, Val: 0.4060, Test: 0.4190
# Epoch: 009, Train: 0.3786, Val: 0.4060, Test: 0.4190
# Epoch: 010, Train: 0.4786, Val: 0.4060, Test: 0.4190
# Epoch: 011, Train: 0.5571, Val: 0.4060, Test: 0.4190
# Epoch: 012, Train: 0.6286, Val: 0.4060, Test: 0.4190
# Epoch: 013, Train: 0.6786, Val: 0.4140, Test: 0.3900
# Epoch: 014, Train: 0.7357, Val: 0.4580, Test: 0.4540
# Epoch: 015, Train: 0.7500, Val: 0.4860, Test: 0.4820
# Epoch: 016, Train: 0.7571, Val: 0.5120, Test: 0.4930
# Epoch: 017, Train: 0.8357, Val: 0.5620, Test: 0.5530
# Epoch: 018, Train: 0.8857, Val: 0.7120, Test: 0.6950
# Epoch: 019, Train: 0.9143, Val: 0.7380, Test: 0.7230
# Epoch: 020, Train: 0.9000, Val: 0.7380, Test: 0.7230
# Epoch: 021, Train: 0.8929, Val: 0.7380, Test: 0.7230
# Epoch: 022, Train: 0.9000, Val: 0.7400, Test: 0.7200
# Epoch: 023, Train: 0.9000, Val: 0.7400, Test: 0.7200
# Epoch: 024, Train: 0.8643, Val: 0.7400, Test: 0.7200
# Epoch: 025, Train: 0.8214, Val: 0.7400, Test: 0.7200
# Epoch: 026, Train: 0.8357, Val: 0.7400, Test: 0.7200
# Epoch: 027, Train: 0.8286, Val: 0.7400, Test: 0.7200
# Epoch: 028, Train: 0.8286, Val: 0.7400, Test: 0.7200
# Epoch: 029, Train: 0.8643, Val: 0.7400, Test: 0.7200
# Epoch: 030, Train: 0.8786, Val: 0.7400, Test: 0.7200
# Epoch: 031, Train: 0.8857, Val: 0.7400, Test: 0.7200
# Epoch: 032, Train: 0.8929, Val: 0.7400, Test: 0.7200
# Epoch: 033, Train: 0.8929, Val: 0.7400, Test: 0.7200
# Epoch: 034, Train: 0.9071, Val: 0.7400, Test: 0.7200
# Epoch: 035, Train: 0.9214, Val: 0.7460, Test: 0.7540
# Epoch: 036, Train: 0.9214, Val: 0.7460, Test: 0.7540
# Epoch: 037, Train: 0.9214, Val: 0.7460, Test: 0.7540
# Epoch: 038, Train: 0.9143, Val: 0.7460, Test: 0.7540
# Epoch: 039, Train: 0.9214, Val: 0.7460, Test: 0.7540
# Epoch: 040, Train: 0.9214, Val: 0.7460, Test: 0.7540
# Epoch: 041, Train: 0.9214, Val: 0.7460, Test: 0.7540
# Epoch: 042, Train: 0.9143, Val: 0.7460, Test: 0.7540
# Epoch: 043, Train: 0.9143, Val: 0.7460, Test: 0.7540
# Epoch: 044, Train: 0.9214, Val: 0.7460, Test: 0.7540
# Epoch: 045, Train: 0.9071, Val: 0.7460, Test: 0.7540
# Epoch: 046, Train: 0.9000, Val: 0.7460, Test: 0.7540
# Epoch: 047, Train: 0.8929, Val: 0.7460, Test: 0.7540
# Epoch: 048, Train: 0.8929, Val: 0.7460, Test: 0.7540
# Epoch: 049, Train: 0.8857, Val: 0.7460, Test: 0.7540
# Epoch: 050, Train: 0.8786, Val: 0.7460, Test: 0.7540
# Epoch: 051, Train: 0.9000, Val: 0.7460, Test: 0.7540
# Epoch: 052, Train: 0.9143, Val: 0.7460, Test: 0.7540
# Epoch: 053, Train: 0.9286, Val: 0.7460, Test: 0.7540
# Epoch: 054, Train: 0.9357, Val: 0.7460, Test: 0.7540
# Epoch: 055, Train: 0.9357, Val: 0.7460, Test: 0.7540
# Epoch: 056, Train: 0.9429, Val: 0.7460, Test: 0.7540
# Epoch: 057, Train: 0.9429, Val: 0.7520, Test: 0.7430
# Epoch: 058, Train: 0.9500, Val: 0.7600, Test: 0.7450
# Epoch: 059, Train: 0.9429, Val: 0.7660, Test: 0.7480
# Epoch: 060, Train: 0.9429, Val: 0.7660, Test: 0.7480
# Epoch: 061, Train: 0.9429, Val: 0.7660, Test: 0.7480
# Epoch: 062, Train: 0.9429, Val: 0.7700, Test: 0.7690
# Epoch: 063, Train: 0.9500, Val: 0.7800, Test: 0.7740
# Epoch: 064, Train: 0.9500, Val: 0.7800, Test: 0.7740
# Epoch: 065, Train: 0.9500, Val: 0.7800, Test: 0.7740
# Epoch: 066, Train: 0.9500, Val: 0.7800, Test: 0.7740
# Epoch: 067, Train: 0.9500, Val: 0.7800, Test: 0.7740
# Epoch: 068, Train: 0.9500, Val: 0.7800, Test: 0.7740
# Epoch: 069, Train: 0.9500, Val: 0.7800, Test: 0.7740
# Epoch: 070, Train: 0.9500, Val: 0.7800, Test: 0.7740
# Epoch: 071, Train: 0.9571, Val: 0.7800, Test: 0.7740
# Epoch: 072, Train: 0.9571, Val: 0.7800, Test: 0.7740
# Epoch: 073, Train: 0.9571, Val: 0.7800, Test: 0.7740
# Epoch: 074, Train: 0.9643, Val: 0.7860, Test: 0.7830
# Epoch: 075, Train: 0.9643, Val: 0.7880, Test: 0.7830
# Epoch: 076, Train: 0.9643, Val: 0.7880, Test: 0.7830
# Epoch: 077, Train: 0.9643, Val: 0.7900, Test: 0.7730
# Epoch: 078, Train: 0.9643, Val: 0.7900, Test: 0.7730
# Epoch: 079, Train: 0.9571, Val: 0.7900, Test: 0.7730
# Epoch: 080, Train: 0.9571, Val: 0.7900, Test: 0.7730
# Epoch: 081, Train: 0.9571, Val: 0.7960, Test: 0.7830
# Epoch: 082, Train: 0.9571, Val: 0.7960, Test: 0.7830
# Epoch: 083, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 084, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 085, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 086, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 087, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 088, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 089, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 090, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 091, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 092, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 093, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 094, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 095, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 096, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 097, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 098, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 099, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 100, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 101, Train: 0.9500, Val: 0.7980, Test: 0.7830
# Epoch: 102, Train: 0.9571, Val: 0.7980, Test: 0.7830
# Epoch: 103, Train: 0.9571, Val: 0.7980, Test: 0.7830
# Epoch: 104, Train: 0.9571, Val: 0.7980, Test: 0.7830
# Epoch: 105, Train: 0.9643, Val: 0.7980, Test: 0.7830
# Epoch: 106, Train: 0.9643, Val: 0.8020, Test: 0.7980
# Epoch: 107, Train: 0.9714, Val: 0.8020, Test: 0.7980
# Epoch: 108, Train: 0.9714, Val: 0.8020, Test: 0.7980
# Epoch: 109, Train: 0.9714, Val: 0.8060, Test: 0.7990
# Epoch: 110, Train: 0.9643, Val: 0.8060, Test: 0.7990
# Epoch: 111, Train: 0.9643, Val: 0.8060, Test: 0.7990
# Epoch: 112, Train: 0.9643, Val: 0.8060, Test: 0.7990
# Epoch: 113, Train: 0.9643, Val: 0.8060, Test: 0.7990
# Epoch: 114, Train: 0.9643, Val: 0.8060, Test: 0.7990
# Epoch: 115, Train: 0.9643, Val: 0.8060, Test: 0.7990
# Epoch: 116, Train: 0.9643, Val: 0.8060, Test: 0.7990
# Epoch: 117, Train: 0.9643, Val: 0.8060, Test: 0.7990
# Epoch: 118, Train: 0.9643, Val: 0.8060, Test: 0.7990
# Epoch: 119, Train: 0.9643, Val: 0.8060, Test: 0.7990
# Epoch: 120, Train: 0.9714, Val: 0.8060, Test: 0.7990
# Epoch: 121, Train: 0.9714, Val: 0.8140, Test: 0.8190
# Epoch: 122, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 123, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 124, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 125, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 126, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 127, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 128, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 129, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 130, Train: 0.9714, Val: 0.8140, Test: 0.8190
# Epoch: 131, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 132, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 133, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 134, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 135, Train: 0.9714, Val: 0.8140, Test: 0.8190
# Epoch: 136, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 137, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 138, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 139, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 140, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 141, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 142, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 143, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 144, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 145, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 146, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 147, Train: 0.9786, Val: 0.8140, Test: 0.8190
# Epoch: 148, Train: 0.9714, Val: 0.8140, Test: 0.8190
# Epoch: 149, Train: 0.9714, Val: 0.8140, Test: 0.8190
# Epoch: 150, Train: 0.9714, Val: 0.8140, Test: 0.8190
# Epoch: 151, Train: 0.9714, Val: 0.8140, Test: 0.8190
# Epoch: 152, Train: 0.9714, Val: 0.8140, Test: 0.8190
# Epoch: 153, Train: 0.9714, Val: 0.8140, Test: 0.8190
# Epoch: 154, Train: 0.9714, Val: 0.8140, Test: 0.8190
# Epoch: 155, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 156, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 157, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 158, Train: 0.9929, Val: 0.8140, Test: 0.8190
# Epoch: 159, Train: 0.9929, Val: 0.8140, Test: 0.8190
# Epoch: 160, Train: 0.9929, Val: 0.8140, Test: 0.8190
# Epoch: 161, Train: 0.9929, Val: 0.8140, Test: 0.8190
# Epoch: 162, Train: 0.9929, Val: 0.8140, Test: 0.8190
# Epoch: 163, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 164, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 165, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 166, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 167, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 168, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 169, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 170, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 171, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 172, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 173, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 174, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 175, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 176, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 177, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 178, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 179, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 180, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 181, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 182, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 183, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 184, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 185, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 186, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 187, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 188, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 189, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 190, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 191, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 192, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 193, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 194, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 195, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 196, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 197, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 198, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 199, Train: 0.9857, Val: 0.8140, Test: 0.8190
# Epoch: 200, Train: 0.9857, Val: 0.8140, Test: 0.8190
