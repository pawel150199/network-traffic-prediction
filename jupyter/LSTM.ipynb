# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import tqdm

# create the dataset 
x_values = [i for i in range(11)]
x_train = np.array(x_values, dtype=np.float32)
x_train = x_train.reshape(-1, 1)

y_values = [2*i + 1 for i in x_values]
y_train = np.array(y_values, dtype=np.float32)
y_train = y_train.reshape(-1, 1)

class LinearRegression(nn.Module):
    def __init__(self, input_dim: int, output_dim: int):
        super(LinearRegression, self).__init__()
        self.linear = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        out = self.linear(x)
        return out


if __name__ == "__main__":
    input_dim = 1
    output_dim = 1
    learning_rate = 0.01

    model = LinearRegression(input_dim=input_dim, output_dim=output_dim)
    criterion = nn.MSELoss()
    params_to_optimize = model.parameters()
    optimizer = torch.optim.SGD(params_to_optimize, lr=learning_rate)


    # train
    epochs = 100
    for epoch in range(epochs):
        epochs += 1
        inputs = Variable(torch.from_numpy(x_train))
        labels = Variable(torch.from_numpy(y_train))

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        print('epoch {}, loss {}'.format(epoch, loss.data))
# Out:
# epoch 0, loss 291.4389953613281
# epoch 1, loss 24.02643585205078
# epoch 2, loss 2.21158766746521
# epoch 3, loss 0.4294087588787079
# epoch 4, loss 0.2812604308128357
# epoch 5, loss 0.2664269208908081
# epoch 6, loss 0.2624979615211487
# epoch 7, loss 0.259488970041275
# epoch 8, loss 0.25658494234085083
# epoch 9, loss 0.25371912121772766
# epoch 10, loss 0.25088584423065186
# epoch 11, loss 0.24808454513549805
# epoch 12, loss 0.24531397223472595
# epoch 13, loss 0.24257458746433258
# epoch 14, loss 0.2398657351732254
# epoch 15, loss 0.2371872365474701
# epoch 16, loss 0.23453854024410248
# epoch 17, loss 0.23191958665847778
# epoch 18, loss 0.22932960093021393
# epoch 19, loss 0.2267688810825348
# epoch 20, loss 0.22423654794692993
# epoch 21, loss 0.22173276543617249
# epoch 22, loss 0.2192564159631729
# epoch 23, loss 0.21680809557437897
# epoch 24, loss 0.21438711881637573
# epoch 25, loss 0.21199296414852142
# epoch 26, loss 0.20962585508823395
# epoch 27, loss 0.20728491246700287
# epoch 28, loss 0.20497006177902222
# epoch 29, loss 0.20268107950687408
# epoch 30, loss 0.20041804015636444
# epoch 31, loss 0.19817987084388733
# epoch 32, loss 0.195966899394989
# epoch 33, loss 0.19377873837947845
# epoch 34, loss 0.19161467254161835
# epoch 35, loss 0.18947488069534302
# epoch 36, loss 0.18735909461975098
# epoch 37, loss 0.18526695668697357
# epoch 38, loss 0.1831979751586914
# epoch 39, loss 0.18115220963954926
# epoch 40, loss 0.17912955582141876
# epoch 41, loss 0.17712916433811188
# epoch 42, loss 0.175151064991951
# epoch 43, loss 0.1731952577829361
# epoch 44, loss 0.17126129567623138
# epoch 45, loss 0.16934871673583984
# epoch 46, loss 0.1674576997756958
# epoch 47, loss 0.16558760404586792
# epoch 48, loss 0.16373872756958008
# epoch 49, loss 0.16191019117832184
# epoch 50, loss 0.16010195016860962
# epoch 51, loss 0.15831439197063446
# epoch 52, loss 0.15654653310775757
# epoch 53, loss 0.15479809045791626
# epoch 54, loss 0.15306971967220306
# epoch 55, loss 0.15136049687862396
# epoch 56, loss 0.14967019855976105
# epoch 57, loss 0.14799869060516357
# epoch 58, loss 0.14634622633457184
# epoch 59, loss 0.14471188187599182
# epoch 60, loss 0.1430959850549698
# epoch 61, loss 0.14149796962738037
# epoch 62, loss 0.1399179995059967
# epoch 63, loss 0.13835550844669342
# epoch 64, loss 0.13681066036224365
# epoch 65, loss 0.13528276979923248
# epoch 66, loss 0.13377195596694946
# epoch 67, loss 0.1322782039642334
# epoch 68, loss 0.13080109655857086
# epoch 69, loss 0.12934039533138275
# epoch 70, loss 0.12789608538150787
# epoch 71, loss 0.1264680027961731
# epoch 72, loss 0.12505565583705902
# epoch 73, loss 0.12365925312042236
# epoch 74, loss 0.12227838486433029
# epoch 75, loss 0.12091287970542908
# epoch 76, loss 0.11956275254487991
# epoch 77, loss 0.11822769790887833
# epoch 78, loss 0.11690732836723328
# epoch 79, loss 0.11560172587633133
# epoch 80, loss 0.1143108606338501
# epoch 81, loss 0.11303447932004929
# epoch 82, loss 0.11177213490009308
# epoch 83, loss 0.1105240136384964
# epoch 84, loss 0.10928985476493835
# epoch 85, loss 0.10806925594806671
# epoch 86, loss 0.10686265677213669
# epoch 87, loss 0.10566938668489456
# epoch 88, loss 0.1044892817735672
# epoch 89, loss 0.10332250595092773
# epoch 90, loss 0.1021687462925911
# epoch 91, loss 0.1010277271270752
# epoch 92, loss 0.09989965707063675
# epoch 93, loss 0.0987842008471489
# epoch 94, loss 0.09768103808164597
# epoch 95, loss 0.09659022837877274
# epoch 96, loss 0.09551145881414413
# epoch 97, loss 0.09444515407085419
# epoch 98, loss 0.09339039772748947
# epoch 99, loss 0.09234735369682312

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import tqdm

# create the dataset 
x_values = [i for i in range(11)]
x_train = np.array(x_values, dtype=np.float32)
x_train = x_train.reshape(-1, 1)

y_values = [2*i + 1 for i in x_values]
y_train = np.array(y_values, dtype=np.float32)
y_train = y_train.reshape(-1, 1)

class LinearRegression(nn.Module):
    def __init__(self, input_dim: int, output_dim: int):
        super(LinearRegression, self).__init__()
        self.lstm1 = nn.LSTM(input_dim)
        self.dense1 = nn.
        self.linear = nn.Linear(output_dim)

    def forward(self, x):
        out = self.linear(x)
        return out


if __name__ == "__main__":
    input_dim = 1
    output_dim = 1
    learning_rate = 0.01

    model = LinearRegression(input_dim=input_dim, output_dim=output_dim)
    criterion = nn.MSELoss()
    params_to_optimize = model.parameters()
    optimizer = torch.optim.SGD(params_to_optimize, lr=learning_rate)


    # train
    epochs = 100
    for epoch in range(epochs):
        epochs += 1
        inputs = Variable(torch.from_numpy(x_train))
        labels = Variable(torch.from_numpy(y_train))

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        print('epoch {}, loss {}'.format(epoch, loss.data))
